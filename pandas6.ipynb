# %%
import numpy as np
import pandas as pd

# %%
iris = pd.read_csv("iris.data")

# %%
iris
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.assign(sepal_ratio=lambda x : iris["SepalWidth"]/iris["SepalLength"]).head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name  sepal_ratio
# 0          5.1         3.5          1.4         0.2  Iris-setosa     0.686275
# 1          4.9         3.0          1.4         0.2  Iris-setosa     0.612245
# 2          4.7         3.2          1.3         0.2  Iris-setosa     0.680851
# 3          4.6         3.1          1.5         0.2  Iris-setosa     0.673913
# 4          5.0         3.6          1.4         0.2  Iris-setosa     0.720000

# %%
iris.assign(SepalRatio=lambda x: x.SepalWidth / x.SepalLength,
            PetalRatio=lambda x: x.PetalWidth / x.PetalLength,).plot(kind="scatter", x="SepalRatio", y="PetalRatio")
# Out:
# <AxesSubplot:xlabel='SepalRatio', ylabel='PetalRatio'>
